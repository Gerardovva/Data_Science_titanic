# %%
#importat pandas 
import pandas as pd

# %% [markdown]
# # importar dataset

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# Establecer el nombre del pasajero como indice, mostrar las 10 primeras filas

# %%
data=pd.read_csv("titanic.csv", index_col=2)
data.head(10)
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mr. Owen Harris Braund                                     0       3    male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1  female
# Miss. Laina Heikkinen                                      1       3  female
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1       1  female
# Mr. William Henry Allen                                    0       3    male
# Mr. James Moran                                            0       3    male
# Mr. Timothy J McCarthy                                     0       1    male
# Master. Gosta Leonard Palsson                              0       3    male
# Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson           1       3  female
# Mrs. Nicholas (Adele Achem) Nasser                         1       2  female
#
#                                                      Age  \
# Name
# ...

# %%
#informacion del datafreme
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
#numero de filas y de columnas 
df.shape
# Out:
# (887, 8)

# %%
#numero de elementos 
df.size
# Out:
# 7096

# %%
# muestra los 10 ulyimos registros
df.tail()
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 882         0       2            Rev. Juozas Montvila    male  27.0
# 883         1       1     Miss. Margaret Edith Graham  female  19.0
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1       1            Mr. Karl Howell Behr    male  26.0
# 886         0       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 882                        0                        0  13.00
# 883                        0                        0  30.00
# 884                        1                        2  23.45
# 885                        0                        0  30.00
# 886                        0                        0   7.75

# %% [markdown]
# # Renombrar y acceder al dataframe

# %%
#se renombro la columna Fare por tiket_price
df.rename(columns={"Fare":"Ticket_price"})
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# ...

# %%
# se accede al elemento por posicion 
df.iloc[0,3]
# Out:
# 'male'

# %%
#se accede al elemento por nombre 
df.loc[0,"Sex"]
# Out:
# 'male'

# %% [markdown]
# Creacion de un dataframe con los nombres de los pasajeros y su edad

# %%
data1=df.loc[:,["Name","Age"]]
data1.head(10)
# Out:
#                                                 Name   Age
# 0                             Mr. Owen Harris Braund  22.0
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0
# 2                              Miss. Laina Heikkinen  26.0
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0
# 4                            Mr. William Henry Allen  35.0
# 5                                    Mr. James Moran  27.0
# 6                             Mr. Timothy J McCarthy  54.0
# 7                      Master. Gosta Leonard Palsson   2.0
# 8   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  27.0
# 9                 Mrs. Nicholas (Adele Achem) Nasser  14.0

# %% [markdown]
# Creacion de un dataframe con los 5 primeros registros

# %%
data2=df.loc[:4,:] # traer todos los registros hasta el numero 4 y todas las columnas 
data2
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# dataframe dividido

# %%
df.shape[0]/2
# Out:
# 443.5

# %%
df1=df.iloc[:443,:]
df1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 438         0       3                                     Mr. Leon Hampe
# 439         0       3                           Mr. Johan Emil Petterson
# 440         1       2                           Ms. Encarnacion Reynaldo
# 441         1       3                   Mr. Bernt Johannesen-Bratthammer
# 442         1       1                           Master. Washington Dodge
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
df1=df.iloc[443: ,:]
df1
# Out:
#      Survived  Pclass                              Name     Sex   Age  \
# 443         1       2  Miss. Madeleine Violet Mellinger  female  13.0
# 444         1       1        Mr. Frederic Kimber Seward    male  34.0
# 445         1       3     Miss. Marie Catherine Baclini  female   5.0
# 446         1       1     Major. Arthur Godfrey Peuchen    male  52.0
# 447         0       2              Mr. Edwy Arthur West    male  36.0
# ..        ...     ...                               ...     ...   ...
# 882         0       2              Rev. Juozas Montvila    male  27.0
# 883         1       1       Miss. Margaret Edith Graham  female  19.0
# 884         0       3    Miss. Catherine Helen Johnston  female   7.0
# 885         1       1              Mr. Karl Howell Behr    male  26.0
# 886         0       3                Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 443                        0                        1  19.5000
# ...

# %%
#Eliminar columna 
df1.pop("Name")
# Out:
# 443    Miss. Madeleine Violet Mellinger
# 444          Mr. Frederic Kimber Seward
# 445       Miss. Marie Catherine Baclini
# 446       Major. Arthur Godfrey Peuchen
# 447                Mr. Edwy Arthur West
#                      ...
# 882                Rev. Juozas Montvila
# 883         Miss. Margaret Edith Graham
# 884      Miss. Catherine Helen Johnston
# 885                Mr. Karl Howell Behr
# 886                  Mr. Patrick Dooley
# Name: Name, Length: 444, dtype: object

# %%
# verificar si la columna fue eliminada 
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df1.drop("Survived",axis=1)
# Out:
#      Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 443       2  female  13.0                        0                        1
# 444       1    male  34.0                        0                        0
# 445       3  female   5.0                        2                        1
# 446       1    male  52.0                        0                        0
# 447       2    male  36.0                        1                        2
# ..      ...     ...   ...                      ...                      ...
# 882       2    male  27.0                        0                        0
# 883       1  female  19.0                        0                        0
# 884       3  female   7.0                        1                        2
# 885       1    male  26.0                        0                        0
# 886       3    male  32.0                        0                        0
#
#         Fare
# 443  19.5000
# 444  26.5500
# ...

# %% [markdown]
# añadir columna ticket/edad

# %%
df["Precio/Age"]=df["Fare"]/df["Age"]
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %% [markdown]
# # Analis descriptivo

# %%
#conteo de las filas 
df.count()
# Out:
# Survived                   887
# Pclass                     887
# Name                       887
# Sex                        887
# Age                        887
# Siblings/Spouses Aboard    887
# Parents/Children Aboard    887
# Fare                       887
# Precio/Age                 887
# dtype: int64

# %%
# cuantas personas an sobrevivido
df['Survived'].sum()
# Out:
# 342

# %%
#suma acomulada
df['Survived'].cumsum()
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        3
#       ...
# 882    340
# 883    341
# 884    341
# 885    342
# 886    342
# Name: Survived, Length: 887, dtype: int64

# %%
#maximo y minima edad 
df["Age"].max()
# Out:
# 80.0

# %%
df[df["Age"]==80]
# Out:
#      Survived  Pclass                                 Name   Sex   Age  \
# 627         1       1  Mr. Algernon Henry Wilson Barkworth  male  80.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard  Fare  Precio/Age
# 627                        0                        0  30.0       0.375

# %%
#edad minima
df["Age"].min()
# Out:
# 0.42

# %%
df[df["Age"] ==0.42]
# Out:
#      Survived  Pclass                            Name   Sex   Age  \
# 799         1       3  Master. Assad Alexander Thomas  male  0.42
#
#      Siblings/Spouses Aboard  Parents/Children Aboard    Fare  Precio/Age
# 799                        0                        1  8.5167   20.277857

# %%
#maximo de cada columna 
df.max()
# Out:
# Survived                                                                   1
# Pclass                                                                     3
# Name                       the Countess. of (Lucy Noel Martha Dyer-Edward...
# Sex                                                                     male
# Age                                                                     80.0
# Siblings/Spouses Aboard                                                    8
# Parents/Children Aboard                                                    6
# Fare                                                                512.3292
# Precio/Age                                                        164.728261
# dtype: object

# %%
#Resumen estadistico
df.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare  Precio/Age
# count               887.000000  887.00000  887.000000
# mean                  0.383315   32.30542    2.127888
# std                   0.807466   49.78204    7.344015
# min                   0.000000    0.00000    0.000000
# 25%                   0.000000    7.92500    0.329545
# ...

# %% [markdown]
# **Calcular la tarifa media de los pasajeros del titanic y crea una nueva columna llamada "Fare/mean Fare" donde calcules el ratio entre la tarifa que ha pagado cada pasajero entre la tarifa media**

# %%
media=df["Fare"].mean()
media
# Out:
# 32.30542018038331

# %%
df["Fare/mean_Fare"]=df["Fare"]/media
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                        1                        0   7.2500
# ...

# %% [markdown]
# **Muestra el precio mas elevado y el precio mas bajo de un ticket para le titanic. Tambien muestra la recaudacion total del titanic por venta de los ticket**

# %%
bajo=df["Fare"].min()
alto=df["Fare"].max()
suma=df["Fare"].sum()

# %%
print(f"precio mas bajo: {bajo} dolares")
print(f"precio mas alto: {alto} dolares")
print(f"total de venta: {suma} dolares")
# Out:
# precio mas bajo: 0.0 dolares
# precio mas alto: 512.3292 dolares
# total de venta: 28654.907699999996 dolares

# %% [markdown]
# # filtrado de filas

# %%
# cuál es el registro del pasajero mas viejo en el titanic

df[(df["Age"]==df["Age"].max())]
# Out:
#      Survived  Pclass                                 Name   Sex   Age  \
# 627         1       1  Mr. Algernon Henry Wilson Barkworth  male  80.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard  Fare  Precio/Age  \
# 627                        0                        0  30.0       0.375
#
#      Fare/mean_Fare
# 627        0.928637

# %%
# mostrar pasajeros que sobrevivieron y eran mayores de 60 años 
df[ (df["Survived"]==1)&(df["Age"]>60) ]
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 273         1       1          Miss. Kornelia Theodosia Andrews  female  63.0
# 480         1       3                     Mrs. (Hedwig) Turkula  female  63.0
# 567         1       2                         Mr. George Harris    male  62.0
# 627         1       1       Mr. Algernon Henry Wilson Barkworth    male  80.0
# 825         1       1  Mrs. George Nelson (Martha Evelyn) Stone  female  62.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Precio/Age  \
# 273                        1                        0  77.9583    1.237433
# 480                        0                        0   9.5875    0.152183
# 567                        0                        0  10.5000    0.169355
# 627                        0                        0  30.0000    0.375000
# 825                        0                        0  80.0000    1.290323
#
#      Fare/mean_Fare
# 273        2.413165
# ...

# %%
# Muestra los pasajeros que tuvieron algun familiar a bordo y no sobrevivieron 
df[((df["Siblings/Spouses Aboard"]!=0)|(df["Parents/Children Aboard"]!=0))&(df["Survived"]==0)]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 7           0       3                      Master. Gosta Leonard Palsson
# 13          0       3                         Mr. Anders Johan Andersson
# 16          0       3                                Master. Eugene Rice
# 18          0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# ..        ...     ...                                                ...
# 856         0       3                             Mr. Claus Peter Hansen
# 857         0       2                         Mr. Frederick Edward Giles
# 859         0       3                           Miss. Dorothy Edith Sage
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 884         0       3                     Miss. Catherine Helen Johnston
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# ...

# %%
# muestra un dataframe solo con columnas que acaben en e
df.filter(regex="e$",axis=1) #indica palabra terminada en e
# Out:
#                                                   Name   Age     Fare  \
# 0                               Mr. Owen Harris Braund  22.0   7.2500
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0  71.2833
# 2                                Miss. Laina Heikkinen  26.0   7.9250
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0  53.1000
# 4                              Mr. William Henry Allen  35.0   8.0500
# ..                                                 ...   ...      ...
# 882                               Rev. Juozas Montvila  27.0  13.0000
# 883                        Miss. Margaret Edith Graham  19.0  30.0000
# 884                     Miss. Catherine Helen Johnston   7.0  23.4500
# 885                               Mr. Karl Howell Behr  26.0  30.0000
# 886                                 Mr. Patrick Dooley  32.0   7.7500
#
#      Precio/Age  Fare/mean_Fare
# 0      0.329545        0.224421
# 1      1.875876        2.206543
# ...

# %%
#muestra un dataframe solo con las filas que tengan "Mary" en el nombre 
data.filter(like="Mary",axis=0)
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mrs. (Mary D Kingcome) Hewlett                             1       2  female
# Miss. Mary Agatha Glynn                                    1       3  female
# Miss. Mary Natalie Wick                                    1       1  female
# Miss. Hilda Mary Slayter                                   1       2  female
# Mrs. Thomas Henry (Mary E Finck) Davison                   1       3  female
# Miss. Mary McGovern                                        1       3  female
# Miss. Helen Mary Mockler                                   1       3  female
# Mrs. Alexander Oskar (Mary Aline Towner) Holverson         1       1  female
# Mrs. Edwy Arthur (Ada Mary Worth) West                     1       2  female
# Miss. Mary Canavan                                         0       3  female
# Miss. Bridget Mary O'Sullivan                              0       3  female
# ...

# %% [markdown]
# Cuantos pasajeros pagaron por el ticket mas de la media y sibrevivieron

# %%
df[(df["Fare"]>df["Fare"].mean())&(df["Survived"]==1) ]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 23          1       1                        Mr. William Thompson Sloper
# 31          1       1      Mrs. William Augustus (Marie Eugenie) Spencer
# 42          1       2            Miss. Simonne Marie Anne Andree Laroche
# ..        ...     ...                                                ...
# 845         1       1        Mrs. Samuel L (Edwiga Grabowska) Goldenberg
# 849         1       1                           Miss. Mary Conover Lines
# 852         1       1          Mrs. George Dennick (Mary Hitchcock) Wick
# 867         1       1    Mrs. Richard Leonard (Sallie Monypeny) Beckwith
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard      Fare  \
# ...

# %% [markdown]
# Crea un dataframe que contenga todas las columnas que empiecen por "A"

# %%
df.filter(regex="^A", axis=1)
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 882  27.0
# 883  19.0
# 884   7.0
# 885  26.0
# 886  32.0
#
# [887 rows x 1 columns]

# %% [markdown]
# ordenar un dataframe

# %%
#ordenar pasajeros por edad 
df.sort_values("Age",ascending=True)
# Out:
#      Survived  Pclass                                 Name     Sex    Age  \
# 799         1       3       Master. Assad Alexander Thomas    male   0.42
# 751         1       2             Master. Viljo Hamalainen    male   0.67
# 641         1       3                Miss. Eugenie Baclini  female   0.75
# 466         1       3         Miss. Helene Barbara Baclini  female   0.75
# 827         1       2       Master. George Sibley Richards    male   0.83
# ..        ...     ...                                  ...     ...    ...
# 115         0       3                  Mr. Patrick Connors    male  70.50
# 490         0       1               Mr. Ramon Artagaveytia    male  71.00
# 95          0       1             Mr. George B Goldschmidt    male  71.00
# 847         0       3                   Mr. Johan Svensson    male  74.00
# 627         1       1  Mr. Algernon Henry Wilson Barkworth    male  80.00
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Precio/Age  \
# ...

# %%
#ordenar pasajeros por edad (desendente)
df.sort_values("Age",ascending=False)
# Out:
#      Survived  Pclass                                 Name     Sex    Age  \
# 627         1       1  Mr. Algernon Henry Wilson Barkworth    male  80.00
# 847         0       3                   Mr. Johan Svensson    male  74.00
# 490         0       1               Mr. Ramon Artagaveytia    male  71.00
# 95          0       1             Mr. George B Goldschmidt    male  71.00
# 115         0       3                  Mr. Patrick Connors    male  70.50
# ..        ...     ...                                  ...     ...    ...
# 77          1       2         Master. Alden Gates Caldwell    male   0.83
# 466         1       3         Miss. Helene Barbara Baclini  female   0.75
# 641         1       3                Miss. Eugenie Baclini  female   0.75
# 751         1       2             Master. Viljo Hamalainen    male   0.67
# 799         1       3       Master. Assad Alexander Thomas    male   0.42
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Precio/Age  \
# ...

# %% [markdown]
# # Predecir quien sobrevive en el hundimiento del titanic

# %% [markdown]
# # 1.Practica Supervivencia en el Titanic

# %% [markdown]
# ## 1.1 Cargando los datos
